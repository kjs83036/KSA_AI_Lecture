# %% [markdown]
# 기초 수학

# %% [markdown]
# 벡터

# %%
import numpy as np
import time

a = np.array([2, 1])
print(a)
type(a)
# Out:
# [2 1]
# numpy.ndarray

# %%
c = np.array([[1, 2], [3, 4]])
d = np.array([[1], [2]])
d
# Out:
# array([[1],
#        [2]])

# %%
d.T
# Out:
# array([[1, 2]])

# %%
a + d.T
# Out:
# array([[3, 3]])

# %%
c + d
# Out:
# array([[2, 3],
#        [5, 6]])

# %%
e = np.array([1, 3])
f = np.array([4, 2])
e.dot(f)
# Out:
# 10

# %%
np.linalg.norm(c)
# Out:
# 5.477225575051661

# %%
a = np.ones(1000)
b = np.arange(1, 1001)
startTime = time.clock()
sum2 = a.dot(b)
endTime = time.clock() - startTime
print(endTime)
# Out:
# 0.0002115000000060263

# %%
import time


sum1 = 0
startTime = time.clock()
for i in range(1, 1001):
    sum1 += i
endTime = time.clock() - startTime
print(endTime)
# Out:
# 0.0001415999999920814

# %% [markdown]
# 미분

# %%
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D


matplotlib.rcParams['axes.unicode_minus'] = False
def f(w0, w1):
    return w0**2 + 2*w0*w1 + 3

def df_dw0(w0, w1):
    return 2*w0 + 2*w1

def df_dw1(w0, w1):
    return 2*w0

w_range = 2
dw = 0.25

w0 = np.arange(-w_range, w_range + dw, dw)
w1 = np.arange(-w_range, w_range + dw, dw)
wn = w0.shape[0]
ww0, ww1 = np.meshgrid(w0, w1)
ff = np.zeros((len(w0), len(w1)))
dff_dw0 = np.zeros((len(w0), len(w1)))
dff_dw1 = np.zeros((len(w0), len(w1)))
for i0 in range(wn):
    for i1 in range(wn):
        ff[i1, i0] = f(w0[i0], w1[i1])
        dff_dw0[i1, i0] = df_dw0(w0[i0], w1[i1])
        dff_dw1[i1, i0] = df_dw1(w0[i0], w1[i1])

plt.figure(figsize=(9, 4))
plt.subplots_adjust(wspace=0.3)
plt.subplot(1, 2, 1)
cont = plt.contour(ww0, ww1, ff, 10, colors="k")
cont.clabel(fmt="%2.0f", fontsize=8)
#plt.xticks(range(-w_range, w_range +1, 1))
plt.yticks(range(-w_range, w_range +1, 1))
plt.xlim(-w_range - 0.5, w_range + .5)
plt.ylim(-w_range - .5, w_range + .5)
plt.xlabel("$w_0$", fontsize=14)
plt.ylabel("$w_1$", fontsize=14)


plt.subplot(1, 2, 2)
plt.quiver(ww0, ww1, dff_dw0, dff_dw1)
plt.xticks(range(-w_range, w_range +1, 1))
plt.yticks(range(-w_range, w_range +1, 1))
plt.xlim(-w_range - 0.5, w_range + .5)
plt.ylim(-w_range - .5, w_range + .5)
plt.xlabel("$w_0$", fontsize=14)
plt.ylabel("$w_1$", fontsize=14)
plt.show()

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
a.dot(b)
# Out:
# 32

# %%
a * b
# Out:
# array([ 4, 10, 18])

# %%
np.identity(2)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
a = np.array([[1, 2], [3, 4]])
np.linalg.inv(a)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
a.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
X = np.arange(-2, 2, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
ZZ = XX**2 + 2*YY*XX +3
fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, cmap='hot')
ax.plot_wireframe(XX, YY, ZZ)
plt.show()

# %%
X = np.arange(-2, 2, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
ZZ = XX**2 + 2*YY*XX +3
fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
#ax.plot_surface(XX, YY, ZZ, cmap='hot')
ax.plot_wireframe(XX, YY, ZZ)
plt.show()

# %% [markdown]
# 지수 로그

# %%
#%matplotlib inline

x = np.linspace(-4, 4, 100)
y = 2**x
y2 = 3**x
y3 = 0.5**x

plt.figure()
plt.plot(x, y, "black", label="$y=2^x$")
plt.plot(x, y2, "cornflowerblue", label="$y=3^x$")
plt.plot(x, y3, "gray", label="$y=0.5^x$")
plt.grid()
plt.ylim(-2, 6)
plt.legend(loc="upper left")
plt.show()

# %%
x = np.linspace(-8, 8, 100)
y = 2**x

x2 = np.linspace(0.0001, 8, 100)
y2 = np.log(x2) / np.log(2)
plt.plot(x, y, "black")
plt.plot(x2, y2, "blue")
plt.plot(x, x, "black", ls="--")
plt.grid()
plt.ylim(-8, 8)
plt.show()

# %%
y = (x - 1)**2 + 2
logy = np.log(y)

plt.figure()
plt.plot(x, y, "black")
plt.plot(x, logy, "blue")
plt.xticks(range(-4, 5))
plt.yticks(range(-4, 9))
plt.ylim(-4, 8)
plt.xlim(-4, 4)
plt.grid()
plt.show()

# %%
a = 2
y = a**x
dy = np.log(a)*y

plt.figure()
plt.plot(x, y, "black", ls="--")
plt.plot(x, dy, )
plt.grid()
plt.show()

# %%
x = np.linspace(0.0001, 4, 100)
y = np.log(x)
dy = 1 / x

plt.figure()
plt.plot(x, y, "gray", ls="--")
plt.plot(x, dy, "black")
plt.grid()
plt.ylim(-8, 8)
plt.xlim(-1, 4)
plt.show()

# %% [markdown]
# 시그모이드 함수

# %%
x = np.linspace(-10, 10, 100)
y = 1 / (1 + np.exp(-x))

plt.figure()
plt.plot(x, y, "black")
plt.grid()
plt.show()

# %% [markdown]
# 소프트맥스 함수

# %%
def softmax(x0, x1, x2):
    u = np.exp(x0) + np.exp(x1) + np.exp(x2)
    return np.exp(x0) / u, np.exp(x1) / u, np.exp(x2) / u

y = softmax(2, 1, -1)
np.round(y, 2)
# Out:
# array([0.71, 0.26, 0.04])

# %%
np.sum(y)
# Out:
# 1.0

# %%
from mpl_toolkits.mplot3d import Axes3D

xn = 20
x0 = np.linspace(-4, 4, xn)
x1 = np.linspace(-4, 4, xn)

y = np.zeros((xn, xn, 3))
for i0 in range(xn):
    for i1 in range(xn):
        y[i1, i0, :] = softmax(x0[i0], x1[i1], 1)

xx0, xx1 = np.meshgrid(x0, x1)
plt.figure(figsize=(8, 5))
for i in range(2):
    ax = plt.subplot(1, 2, i + 1, projection="3d")
    ax.plot_surface(xx0, xx1, y[:, :, i],
                   rstride=1,
                   cstride=1,
                   alpha=0.3,
                   color="blue",
                   edgecolor="black")
    ax.set_xlabel("$x_0$", fontsize=14)
    ax.set_ylabel("$x_1$", fontsize=14)
    ax.view_init(40, -125)

plt.show()

# %%
fig = plt.figure(figsize=(8, 5))
ax = Axes3D(fig)
ax.plot_surface(xx0, xx1, y[:, :, 2],
                rstride=1,
                cstride=1,
                alpha=0.3,
                color="blue",
                edgecolor="black")
ax.set_xlabel("$x_0$", fontsize=14)
ax.set_ylabel("$x_1$", fontsize=14)
ax.view_init(40, -125)

plt.show()

# %% [markdown]
# 가우스함수

# %%
# %matplotlib qt5

def gauss2(mu, sigma, a):
    return a*np.exp(-(x - mu)**2 / sigma**2)

x = np.linspace(-4, 4, 100)

plt.plot(x, gauss2(0, 1, 1), "black")
plt.plot(x, gauss2(2, 3, 0.5), "gray")
plt.grid()
plt.show()

# %%
def gauss(x, mu, sigma):
    N, D = x.shape
    c1 = 1 / (2 * np.pi)**(D / 2)
    c2 = 1 / (np.linalg.det(sigma)**(1/ 2))
    inv_sigma = np.linalg.inv(sigma)
    c3 = x - mu
    print(c3)
    print(c3.T)
    c4 = np.dot(c3, inv_sigma)

    c5 = np.zeros(N)
    for d in range(D):
        print(c3[:, d])
        c5 = c5 + c4[:, d]*c3[:, d]
        print(c5)
    p = c1 * c2 * np.exp(-c5 / 2)
    return p

x = np.array([[1, 2], [2, 1], [3, 4]])
mu = np.array([1, 2])
sigma = np.array([[1, 0], [0, 1]])
print(gauss(x, mu, sigma))
(x-mu).T
# Out:
# [[ 0  0]
#  [ 1 -1]
#  [ 2  2]]
# [[ 0  1  2]
#  [ 0 -1  2]]
# [0 1 2]
# [0. 1. 4.]
# [ 0 -1  2]
# [0. 2. 8.]
# [0.15915494 0.05854983 0.00291502]
# array([[ 0,  1,  2],
#        [ 0, -1,  2]])

# %%
X_range0 = [-3, 3]
X_range1 = [-3, 3]

def show_contour_gauss(mu, sig):
    xn = 40
    x0 = np.linspace(X_range0[0], X_range0[1], xn)
    x1 = np.linspace(X_range1[0], X_range1[1], xn)
    xx0, xx1 = np.meshgrid(x0, x1)
    x = np.c_[np.reshape(xx0, xn * xn, 1), np.reshape(xx1, xn * xn, 1)]
    print(x.shape)
    f = gauss(x, mu, sig)
    f = f.reshape(xn, xn)
    f = f.T
    cont = plt.contour(xx0, xx1, f, 15, colors="k")
    plt.grid()

def show3d_gauss(ax, mu, sig):
    xn = 40
    x0 = np.linspace(X_range0[0], X_range0[1], xn)
    x1 = np.linspace(X_range1[0], X_range1[1], xn)
    xx0, xx1 = np.meshgrid(x0, x1)
    x = np.c_[np.reshape(xx0, xn * xn, 1), np.reshape(xx1, xn * xn, 1)]
    f = gauss(x, mu, sig)
    f = f.reshape(xn, xn)
    f = f.T
    ax.plot_surface(xx0, xx1, f,
                   rstride=2, cstride=2, alpha=0.3,
                   color="blue", edgecolor="k")

# %%
# %matplotlib inline

mu = np.array([1, 0.5])
sigma = np.array([[2, 1], [1, 1]])
Fig = plt.figure(1, figsize=(7, 3))
Fig.add_subplot(1, 2, 1)
show_contour_gauss(mu, sigma)
Ax = Fig.add_subplot(1, 2, 2, projection="3d")
show3d_gauss(Ax, mu, sigma)
Ax.set_zticks([0.05, 0.10])
Ax.set_xlabel("$x_0$")
Ax.set_ylabel("$x_1$")
Ax.view_init(40, -100)
plt.show()
# Out:
# (1600, 2)

# %%
mu = np.array([0, 0])
sigma = np.array([[2, 1], [5, 4]])
Fig = plt.figure(1, figsize=(7, 3))
Fig.add_subplot(1, 2, 1)
show_contour_gauss(mu, sigma)
Ax = Fig.add_subplot(1, 2, 2, projection="3d")
show3d_gauss(Ax, mu, sigma)
Ax.set_zticks([0.05, 0.10])
Ax.set_xlabel("$x_0$")
Ax.set_ylabel("$x_1$")
Ax.view_init(40, -100)
plt.show()
# Out:
# (1600, 2)
